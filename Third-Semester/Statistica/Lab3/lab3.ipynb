# %%
from random import choices, sample
from math import comb, perm

litere = ["r", "a", "v"]
count = 0

def extrage() -> bool:
    
    extragere = sample(litere, 3, counts=[5,3,2])
    if extragere.count("r") >= 1:
        if extragere.count(extragere[0]) == 3:
            return True
        else:
            return False
            
     
def simulari(nr_simulari):
    
    count = 0
    for i in range(nr_simulari):
        if extrage() == True:
            count += 1
            
    return count/nr_simulari


print(simulari(100000))

# P(B|A) aprox. contor A intersectat B\contor A
# (contor A intersectat B/ nr teste) /(contor A / nr teste)
# P(A int. B)/P(A)

#P(toate rosii) = C(5,3)/C(10,3)
#P(A) = 1 - P(A)negat
# Out:
# 0.08447

# %%
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend

data = [randrange(1,7) for _ in range(500)]
bin_edges = [k+0.5 for k in range(7)]
hist(data, bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black',
alpha = 0.5, label = 'frecvente relative')
# distribution = dict([(?,?) for i in range(1,7)])
# bar(?, ?, width = 0.85, color = 'red', edgecolor = 'black',
# alpha= 0.6, label = 'probabilitati')
legend(loc = 'lower left')
grid()
show()

# %%
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend

data = [randrange(1,7) for _ in range(500)]
bin_edges = [k+0.5 for k in range(7)]
hist(data, bins=bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black',
alpha = 0.5, label = 'frecvente relative')
distribution = dict([(i,1/6) for i in range(1,7)])
bar(distribution.keys(), distribution.values(), width = 0.85, color = 'red', edgecolor = 'black',
alpha= 0.6, label = 'probabilitati')
legend(loc = 'lower left')
grid()
show()

# %%
# Variabile aleatoare
# 6 bile de 1
# 4 bile cu 0
# se scot cu replacement 5 bile
# X -> suma nr de pe bilele extrase

# a) lista de 1000 de val pt X
from scipy.stats import binom
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend
from random import choices

valori = binom.rvs(5,0.5,1000)



# Definim urnă cu bile inscripționate cu 1 și 0
urna = [1] * 6 + [0] * 4  # 6 bile cu 1, 4 bile cu 0

# Generăm lista de 1000 de valori pentru X
n_simulari = 1000
valori_X = [sum(choices(urna, k=5)) for _ in range(n_simulari)]

print(valori_X[:10])  # Afișăm primele 10 valori ca exemplu
# Out:
# [2, 2, 2, 3, 3, 1, 2, 2, 3, 4]

# %%
data = binom.rvs(n=5,p=6/10,size=1000)
print(data)
# Out:
# [2 3 4 3 2 4 2 5 4 3 4 1 5 4 4 4 4 4 1 3 2 2 3 2 2 5 2 2 2 3 4 3 2 4 4 5 2
#  3 3 2 1 2 3 4 3 4 4 5 4 3 1 3 5 3 2 3 3 4 3 4 3 4 2 2 4 4 3 3 3 2 2 1 2 3
#  5 2 4 2 4 3 3 4 3 4 2 5 2 4 5 1 2 4 3 3 3 3 5 2 4 3 4 4 4 5 4 2 2 3 4 2 3
#  4 3 4 3 4 2 3 2 2 4 3 5 1 2 3 1 2 3 3 5 3 3 2 0 4 2 4 2 4 4 4 2 2 3 3 3 1
#  2 5 5 4 4 5 4 2 1 2 2 3 2 3 4 5 4 1 4 3 3 2 2 3 2 4 2 1 4 3 3 4 2 3 2 4 3
#  3 3 3 2 3 4 5 1 3 2 5 2 4 4 2 3 5 3 4 2 4 1 3 4 4 3 4 3 4 3 1 4 3 3 2 1 2
#  3 4 2 4 3 3 3 4 2 2 3 4 2 4 3 4 3 4 3 2 4 2 4 4 1 3 3 3 2 4 1 1 3 4 3 4 3
#  2 5 4 1 2 2 3 2 4 2 4 5 4 2 2 3 2 3 4 1 4 4 2 3 5 4 1 1 5 4 2 3 2 4 2 3 3
#  4 3 2 2 3 4 2 3 3 4 4 4 4 4 4 1 3 3 2 4 2 5 4 3 3 3 2 3 2 4 1 4 3 2 4 2 2
#  2 1 3 4 2 4 4 1 3 2 4 1 3 2 3 4 3 4 4 2 4 2 2 4 3 3 4 2 3 3 3 2 1 3 2 2 2
#  5 3 2 3 4 5 1 3 2 3 4 5 1 4 2 3 3 5 4 1 4 2 2 4 2 2 4 4 2 1 2 3 2 3 1 2 4
#  1 2 3 3 4 1 3 4 3 3 4 2 5 2 3 2 1 1 2 2 4 4 4 3 2 4 2 4 3 3 4 2 3 4 3 4 3
# ...

# %%
data = binom.pmf(k=1,n=5,p=6/10)
print(data)
# Out:
# 0.07679999999999998

# %%
data = binom.rvs(n=5,p=6/10,size=1000)
arr = [2 < x <= 5 for x in data]
sum = 0
for x in arr:
    sum += x
print(sum/len(data))
# Out:
# 0.692
